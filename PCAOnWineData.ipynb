# %%
## Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## load Data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4e2caef3-7316-4a8b-8d8f-3776a51743e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e2caef3-7316-4a8b-8d8f-3776a51743e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving wine.csv to wine (1).csv

# %%
wine = pd.read_csv('wine.csv')

# %%
wine
# Out:
#      Type  Alcohol  Malic   Ash  ...  Color   Hue  Dilution  Proline
# 0       1    14.23   1.71  2.43  ...   5.64  1.04      3.92     1065
# 1       1    13.20   1.78  2.14  ...   4.38  1.05      3.40     1050
# 2       1    13.16   2.36  2.67  ...   5.68  1.03      3.17     1185
# 3       1    14.37   1.95  2.50  ...   7.80  0.86      3.45     1480
# 4       1    13.24   2.59  2.87  ...   4.32  1.04      2.93      735
# ..    ...      ...    ...   ...  ...    ...   ...       ...      ...
# 173     3    13.71   5.65  2.45  ...   7.70  0.64      1.74      740
# 174     3    13.40   3.91  2.48  ...   7.30  0.70      1.56      750
# 175     3    13.27   4.28  2.26  ...  10.20  0.59      1.56      835
# 176     3    13.17   2.59  2.37  ...   9.30  0.60      1.62      840
# 177     3    14.13   4.10  2.74  ...   9.20  0.61      1.60      560
#
# [178 rows x 14 columns]

# %%
wine.head(20)
# Out:
#     Type  Alcohol  Malic   Ash  ...  Color   Hue  Dilution  Proline
# 0      1    14.23   1.71  2.43  ...   5.64  1.04      3.92     1065
# 1      1    13.20   1.78  2.14  ...   4.38  1.05      3.40     1050
# 2      1    13.16   2.36  2.67  ...   5.68  1.03      3.17     1185
# 3      1    14.37   1.95  2.50  ...   7.80  0.86      3.45     1480
# 4      1    13.24   2.59  2.87  ...   4.32  1.04      2.93      735
# 5      1    14.20   1.76  2.45  ...   6.75  1.05      2.85     1450
# 6      1    14.39   1.87  2.45  ...   5.25  1.02      3.58     1290
# 7      1    14.06   2.15  2.61  ...   5.05  1.06      3.58     1295
# 8      1    14.83   1.64  2.17  ...   5.20  1.08      2.85     1045
# 9      1    13.86   1.35  2.27  ...   7.22  1.01      3.55     1045
# 10     1    14.10   2.16  2.30  ...   5.75  1.25      3.17     1510
# 11     1    14.12   1.48  2.32  ...   5.00  1.17      2.82     1280
# 12     1    13.75   1.73  2.41  ...   5.60  1.15      2.90     1320
# ...

# %%
wine.shape
# Out:
# (178, 14)

# %%
wine.dtypes
# Out:
# Type                 int64
# Alcohol            float64
# Malic              float64
# Ash                float64
# Alcalinity         float64
# Magnesium            int64
# Phenols            float64
# Flavanoids         float64
# Nonflavanoids      float64
# Proanthocyanins    float64
# Color              float64
# Hue                float64
# Dilution           float64
# Proline              int64
# dtype: object

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
wine.describe()
# Out:
#              Type     Alcohol       Malic  ...         Hue    Dilution      Proline
# count  178.000000  178.000000  178.000000  ...  178.000000  178.000000   178.000000
# mean     1.938202   13.000618    2.336348  ...    0.957449    2.611685   746.893258
# std      0.775035    0.811827    1.117146  ...    0.228572    0.709990   314.907474
# min      1.000000   11.030000    0.740000  ...    0.480000    1.270000   278.000000
# 25%      1.000000   12.362500    1.602500  ...    0.782500    1.937500   500.500000
# 50%      2.000000   13.050000    1.865000  ...    0.965000    2.780000   673.500000
# 75%      3.000000   13.677500    3.082500  ...    1.120000    3.170000   985.000000
# max      3.000000   14.830000    5.800000  ...    1.710000    4.000000  1680.000000
#
# [8 rows x 14 columns]

# %%
wine.corr()
# Out:
#                      Type   Alcohol     Malic  ...       Hue  Dilution   Proline
# Type             1.000000 -0.328222  0.437776  ... -0.617369 -0.788230 -0.633717
# Alcohol         -0.328222  1.000000  0.094397  ... -0.071747  0.072343  0.643720
# Malic            0.437776  0.094397  1.000000  ... -0.561296 -0.368710 -0.192011
# Ash             -0.049643  0.211545  0.164045  ... -0.074667  0.003911  0.223626
# Alcalinity       0.517859 -0.310235  0.288500  ... -0.273955 -0.276769 -0.440597
# Magnesium       -0.209179  0.270798 -0.054575  ...  0.055398  0.066004  0.393351
# Phenols         -0.719163  0.289101 -0.335167  ...  0.433681  0.699949  0.498115
# Flavanoids      -0.847498  0.236815 -0.411007  ...  0.543479  0.787194  0.494193
# Nonflavanoids    0.489109 -0.155929  0.292977  ... -0.262640 -0.503270 -0.311385
# Proanthocyanins -0.499130  0.136698 -0.220746  ...  0.295544  0.519067  0.330417
# Color            0.265668  0.546364  0.248985  ... -0.521813 -0.428815  0.316100
# ...

# %%
## EDA

# %%
### Preprocessing

# %%
wine.data = wine.iloc[:,1:]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
wine.data.head()
# Out:
#    Alcohol  Malic   Ash  Alcalinity  ...  Color   Hue  Dilution  Proline
# 0    14.23   1.71  2.43        15.6  ...   5.64  1.04      3.92     1065
# 1    13.20   1.78  2.14        11.2  ...   4.38  1.05      3.40     1050
# 2    13.16   2.36  2.67        18.6  ...   5.68  1.03      3.17     1185
# 3    14.37   1.95  2.50        16.8  ...   7.80  0.86      3.45     1480
# 4    13.24   2.59  2.87        21.0  ...   4.32  1.04      2.93      735
#
# [5 rows x 13 columns]

# %%
### Normalization

# %%
from sklearn.preprocessing import scale
wine_normal = scale(wine.data)

# %%
wine_normal
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
## PCA

# %%
from sklearn.decomposition import PCA

# %%
  pca =   PCA()
  pca_values = pca.fit_transform(wine_normal)

# %%
pca_values
# Out:
# array([[ 3.31675081e+00, -1.44346263e+00, -1.65739045e-01, ...,
#         -4.51563395e-01,  5.40810414e-01, -6.62386309e-02],
#        [ 2.20946492e+00,  3.33392887e-01, -2.02645737e+00, ...,
#         -1.42657306e-01,  3.88237741e-01,  3.63650247e-03],
#        [ 2.51674015e+00, -1.03115130e+00,  9.82818670e-01, ...,
#         -2.86672847e-01,  5.83573183e-04,  2.17165104e-02],
#        ...,
#        [-2.67783946e+00, -2.76089913e+00, -9.40941877e-01, ...,
#          5.12492025e-01,  6.98766451e-01,  7.20776948e-02],
#        [-2.38701709e+00, -2.29734668e+00, -5.50696197e-01, ...,
#          2.99821968e-01,  3.39820654e-01, -2.18657605e-02],
#        [-3.20875816e+00, -2.76891957e+00,  1.01391366e+00, ...,
#         -2.29964331e-01, -1.88787963e-01, -3.23964720e-01]])

# %%
pca = PCA(n_components= 6)
pca.fit(wine)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=6, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
### Data Visualization

# %%
sns.pairplot(pd.DataFrame(pca_values))

# %%
### Variance Distribution Regarding PCA

# %%
var = pca.explained_variance_ratio_.cumsum()

# %%
var
# Out:
# array([0.99808763, 0.99982354, 0.99991944, 0.99997076, 0.9999837 ,
#        0.99999243])

# %%
### Cumulative Variance

# %%
var1 = np.cumsum(np.round(var, decimals = 4) * 100)

# %%
var1
# Out:
# array([ 99.81, 199.79, 299.78, 399.78, 499.78, 599.78])

# %%
pca.components_
# Out:
# array([[-1.55934284e-03,  1.65926191e-03, -6.81019030e-04,
#          1.94905197e-04, -4.67130461e-03,  1.78679787e-02,
#          9.89831553e-04,  1.56729290e-03, -1.23086954e-04,
#          6.00609082e-04,  2.32712720e-03,  1.71381131e-04,
#          7.04935892e-04,  9.99821721e-01],
#        [ 2.77861762e-03,  1.20426744e-03,  2.15953126e-03,
#          4.59399561e-03,  2.64607000e-02,  9.99339902e-01,
#          8.74730944e-04, -5.86582556e-05, -1.35399415e-03,
#          5.00222716e-03,  1.51142222e-02, -7.64042527e-04,
#         -3.50068415e-03, -1.77693551e-02],
#        [-1.00919962e-01, -1.83035443e-02, -1.24559463e-01,
#         -5.12928854e-02, -9.28099861e-01,  2.99845440e-02,
#          4.27611042e-02,  9.02671155e-02, -1.37215147e-02,
#          2.62371281e-02, -3.03202978e-01,  2.69922728e-02,
#          7.43661999e-02, -4.62655971e-03],
#        [-1.47645845e-01, -1.36988601e-01, -1.56739376e-01,
#          1.20471220e-02,  3.56990103e-01,  4.75411673e-03,
# ...

# %%
plt.plot(var1, color = 'green')

# %%
x = pca_values[:, 0:1]
y = pca_values[:, 1:2]
# z = pca_values[:2:3]
plt.scatter(x,y)

# %%
finaldf = pd.concat([pd.DataFrame(pca_values[:,0:7], columns = ['pca1','pca2','pca3','pca4','pca5','pca6','pca7']), wine[['Type']]], axis = 1)

# %%
finaldf
# Out:
#          pca1      pca2      pca3      pca4      pca5      pca6      pca7  Type
# 0    3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880  0.596427     1
# 1    2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120  0.053776     1
# 2    2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276  0.424205     1
# 3    3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431 -0.383337     1
# 4    1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520  0.444074     1
# ..        ...       ...       ...       ...       ...       ...       ...   ...
# 173 -3.370524 -2.216289 -0.342570  1.058527 -0.574164 -1.108788  0.958416     3
# 174 -2.601956 -1.757229  0.207581  0.349496  0.255063 -0.026465  0.146894     3
# 175 -2.677839 -2.760899 -0.940942  0.312035  1.271355  0.273068  0.679235     3
# 176 -2.387017 -2.297347 -0.550696 -0.688285  0.813955  1.178783  0.633975     3
# 177 -3.208758 -2.768920  1.013914  0.596903 -0.895193  0.296092  0.005741     3
#
# ...

# %%
sns.scatterplot(data = finaldf, x = 'pca1', y = 'pca2', hue = 'Type')

# %%
pcavalues = pd.DataFrame(pca_values[:,:7], columns = ['pca1', 'pca2', 'pca3', 'pca4', 'pca5','pca6','pca7'])

# %%
pcavalues
# Out:
#          pca1      pca2      pca3      pca4      pca5      pca6      pca7
# 0    3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880  0.596427
# 1    2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120  0.053776
# 2    2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276  0.424205
# 3    3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431 -0.383337
# 4    1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520  0.444074
# ..        ...       ...       ...       ...       ...       ...       ...
# 173 -3.370524 -2.216289 -0.342570  1.058527 -0.574164 -1.108788  0.958416
# 174 -2.601956 -1.757229  0.207581  0.349496  0.255063 -0.026465  0.146894
# 175 -2.677839 -2.760899 -0.940942  0.312035  1.271355  0.273068  0.679235
# 176 -2.387017 -2.297347 -0.550696 -0.688285  0.813955  1.178783  0.633975
# 177 -3.208758 -2.768920  1.013914  0.596903 -0.895193  0.296092  0.005741
#
# [178 rows x 7 columns]

# %%
## Hierarchichal Clustering

# %%
import scipy.cluster.hierarchy as sch

# %%
dendrogram = sch.dendrogram(sch.linkage(pcavalues, method = 'complete'))

# %%
#### Inference: No any inference is found from dendrogram, so we will go for K-Means Clustering.

# %%
## K-Means Clustering

# %%
from sklearn.cluster import KMeans

# %%
from scipy.spatial.distance import cdist

# %%
k = list(range(2,8))
k
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
k = list(range(2,8))
k
TWSS = [] # variable for storing total within sum of squares for each kmeans 
for i in k:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(pcavalues)
    WSS = [] # variable for storing within sum of squares for each cluster 
    for j in range(i):
        WSS.append(sum(cdist(pcavalues.iloc[kmeans.labels_==j,:],kmeans.cluster_centers_[j].reshape(1,pcavalues.shape[1]),"euclidean")))
    TWSS.append(sum(WSS))
    
TWSS
# Out:
# [array([476.33742445]),
#  array([397.07929718]),
#  array([378.7134189]),
#  array([364.66219678]),
#  array([351.51700753]),
#  array([343.06013791])]

# %%
#### Elbow Chart

# %%
plt.plot(k,TWSS, 'ro-');plt.xlabel("No_of_Clusters");plt.ylabel("total_within_SS");plt.xticks(k)
# Out:
# ([<matplotlib.axis.XTick at 0x7fabad4d06d0>,
# ...
#  <a list of 6 Text major ticklabel objects>)

# %%
kmeans_clust=KMeans(n_clusters=5)
kmeans_clust.fit(pcavalues)
Clusters=pd.DataFrame(kmeans_clust.labels_,columns=['Clusters'])
Clusters
# Out:
#      Clusters
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 173         2
# 174         2
# 175         2
# 176         2
# 177         2
#
# [178 rows x 1 columns]

# %%
wine['h_clusterid'] = pd.DataFrame(Clusters)

# %%
wine
# Out:
#      Type  Alcohol  Malic   Ash  ...   Hue  Dilution  Proline  h_clusterid
# 0       1    14.23   1.71  2.43  ...  1.04      3.92     1065            1
# 1       1    13.20   1.78  2.14  ...  1.05      3.40     1050            1
# 2       1    13.16   2.36  2.67  ...  1.03      3.17     1185            1
# 3       1    14.37   1.95  2.50  ...  0.86      3.45     1480            1
# 4       1    13.24   2.59  2.87  ...  1.04      2.93      735            1
# ..    ...      ...    ...   ...  ...   ...       ...      ...          ...
# 173     3    13.71   5.65  2.45  ...  0.64      1.74      740            2
# 174     3    13.40   3.91  2.48  ...  0.70      1.56      750            2
# 175     3    13.27   4.28  2.26  ...  0.59      1.56      835            2
# 176     3    13.17   2.59  2.37  ...  0.60      1.62      840            2
# 177     3    14.13   4.10  2.74  ...  0.61      1.60      560            2
#
# [178 rows x 15 columns]

# %%
### Grouping Data

# %%
result=wine.iloc[:,1:].groupby(wine.h_clusterid).mean()

# %%
result
# Out:
#                Alcohol     Malic       Ash  ...  Dilution      Proline  h_clusterid
# h_clusterid                                 ...
# 0            12.086364  2.054545  2.520000  ...  2.767273   496.318182            0
# 1            13.736207  1.930172  2.449138  ...  3.159310  1124.206897            1
# 2            13.157708  3.386042  2.437083  ...  1.698542   627.500000            2
# 3            12.348286  2.082857  2.174857  ...  3.056571   509.342857            3
# 4            12.516667  1.552667  2.043333  ...  2.150000   591.800000            4
#
# [5 rows x 14 columns]
